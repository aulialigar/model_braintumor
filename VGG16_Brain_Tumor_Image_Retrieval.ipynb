# %% [markdown]
# <a href="https://colab.research.google.com/github/aulialigar/model_braintumor/blob/main/VGG16_Brain_Tumor_Image_Retrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Data and Depedency

# %%
# !wget --no-check-certificate \
  https://github.com/aulialigar/braintumor-image/archive/refs/heads/dataset-dan-model.zip\
  -O /tmp/BrainTumorRetrieval.zip
# Out:
# --2022-01-18 16:30:32--  https://github.com/aulialigar/braintumor-image/archive/refs/heads/dataset-dan-model.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/aulialigar/braintumor-image/zip/refs/heads/dataset-dan-model [following]
# --2022-01-18 16:30:32--  https://codeload.github.com/aulialigar/braintumor-image/zip/refs/heads/dataset-dan-model
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘/tmp/BrainTumorRetrieval.zip’
#
# /tmp/BrainTumorRetr     [          <=>       ] 838.52M  15.0MB/s    in 37s
#
# 2022-01-18 16:31:10 (22.6 MB/s) - ‘/tmp/BrainTumorRetrieval.zip’ saved [879249415]

# %%
# !unzip \*.zip &> /dev/null && rm *.zip
import zipfile
zip_ref = zipfile.ZipFile('/tmp/BrainTumorRetrieval.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('/tmp') #Extracts the files into the /tmp folder
zip_ref.close()

# %%
import os
base_dir = '/tmp/braintumor-image-dataset-dan-model/BrainTumorRetrieval'

train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')
val_dir = os.path.join(base_dir, 'valid')

train_glioma_dir = os.path.join(train_dir, 'glioma')
train_meningioma_dir = os.path.join(train_dir, 'meningioma')
train_pituitary_dir = os.path.join(train_dir, 'pituitary')

test_glioma_dir = os.path.join(test_dir, 'glioma')
test_meningioma_dir = os.path.join(test_dir, 'meningioma')
test_pituitary_dir = os.path.join(test_dir, 'pituitary')

val_glioma_dir = os.path.join(val_dir, 'glioma')
val_meningioma_dir = os.path.join(val_dir, 'meningioma')
val_pituitary_dir = os.path.join(val_dir, 'pituitary')

# %%
# Cek penamaan image yang ada di folder train_benign_dir dan train_malignant_dir
print(os.listdir(train_glioma_dir)[:10])
print(os.listdir(train_meningioma_dir)[:10])
print(os.listdir(train_pituitary_dir)[:10])
# Out:
# ['277.png', '787.png', '285.png', '20.png', '635.png', '205.png', '1147.png', '653.png', '99.png', '844.png']
# ['2471.png', '2556.png', '2491.png', '2553.png', '2462.png', '2529.png', '2762.png', '2696.png', '2656.png', '2812.png']
# ['2023.png', '1576.png', '1763.png', '1811.png', '1773.png', '1064.png', '1042.png', '1549.png', '932.png', '1040.png']

# %%
print('total training glioma images:', len(os.listdir(train_glioma_dir)))
print('total training meningioma images:', len(os.listdir(train_meningioma_dir)))
print('total training pituitary images:', len(os.listdir(train_pituitary_dir)))
print('total test glioma images:', len(os.listdir(test_glioma_dir)))
print('total test meningioma images:', len(os.listdir(test_meningioma_dir)))
print('total test pituitary images:', len(os.listdir(test_pituitary_dir)))
print('total val glioma images:', len(os.listdir(val_glioma_dir)))
print('total val meningioma images:', len(os.listdir(val_meningioma_dir)))
print('total val pituitary images:', len(os.listdir(val_pituitary_dir)))
# Out:
# total training glioma images: 998
# total training meningioma images: 495
# total training pituitary images: 651
# total test glioma images: 285
# total test meningioma images: 142
# total test pituitary images: 186
# total val glioma images: 143
# total val meningioma images: 71
# total val pituitary images: 93

# %% [markdown]
# ## Depedency Library

# %%
import numpy as np
import json
import os
import cv2
import copy
import sklearn.metrics as metric
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers
from keras.layers import Input, Lambda, Dense, Flatten, Conv1D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint 
from tensorflow.keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# # Training Stage

# %% [markdown]
# ## Core Model VGG16

# %%
# Menambahkan Layer untuk Preprocessing pada VGG
vgg16 = VGG16(
            input_shape = (128, 128, 3),
            weights = 'imagenet',
            include_top=False)


# Untuk perintah menolak men training data yang telah digunakan sebelumnya
for layer in vgg16.layers:
  layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %% [markdown]
# ## Definition of hyperparameter

# %%
EPOCHS = 100
INIT_LR = 1e-4
BS = 16
IMAGE_SIZE = (128, 128)
checkpoint_path = "training_3_subclass_cp/cp.ckpt"
feature_path = "training_3_subclass_feature.json"
model_path = "training_3_subclass_model.h5"
history_path = "training_3_subclass_history.json"
# magnification = "40X"
# base_path = "/content/drive/MyDrive/"
# base_dataset = "BrainTumorRetrieval"
class_dir = ['glioma', 'meningioma', 'pituitary']

# %%
print("[INFO] indexing file images dataset...")
type_dataset = ['valid', 'train']
dataset_train = []
dataset_val = []
for type_set in type_dataset:
    for class_item in class_dir:
        cur_dir = os.path.join(base_dir, type_set, class_item)
        for file in os.listdir(cur_dir): 
            if type_set == 'train':
                dataset_train.append(os.path.join(cur_dir, file))
            else:
                dataset_val.append(os.path.join(cur_dir, file))

print("[INFO] load images dataset...")
#  load images
train_images = [] 
val_images = []
for type_set in type_dataset:
    cur_dataset = dataset_train if type_set == 'train' else dataset_val
    for image_path in cur_dataset: 
        if ".png" in image_path:
            image = cv2.imread(image_path)
            image = cv2.resize(image, IMAGE_SIZE)
            if type_set == 'train':
                train_images.append(image)
            else:
                val_images.append(image)
# Out:
# [INFO] indexing file images dataset...
# [INFO] load images dataset...

# %% [markdown]
# ## Normalization

# %%
# # normalization
print("[INFO] normalization...")
train_x = np.array(train_images).astype("float32") / 255.0
val_x = np.array(val_images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %% [markdown]
# ## Buiding Model based VGG 16

# %%
x = Conv1D(filters=16, kernel_size=3, strides=1, padding='same', activation='relu', input_shape=(3, 224, 224))
x = Conv1D(filters=16, kernel_size=3, strides=1, padding='same', activation='relu',  input_shape=(64, 224, 224))
x = MaxPooling2D(pool_size=(2, 2), strides=2, padding="valid")
x = Flatten()(vgg16.output)
x = Dense(512, activation='relu')(x)
x = Dense(128, activation='relu')(x)
# x = Dense(64, activation='relu')(x)


# Lapisan Terakhir dengan aktivasi sigmoid untuk output biner 
prediction = Dense(3, activation='sigmoid')(x)

# %%
print("[INFO] building auto encoder...")
# vgg16 = VGG16Model.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
# Membuat obbjek model 
vgg16 = Model(inputs=vgg16.input, outputs=prediction)
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_loss",
    verbose = 1,
    mode='min',
    save_best_only=True)
vgg16.compile(loss="categorical_crossentropy", optimizer=opt, metrics='accuracy')
vgg16.summary()
# Out:
# [INFO] building auto encoder...
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 16, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 512)               4194816
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 18,975,555
# Trainable params: 4,260,867
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory(train_dir,
                                                 target_size = (128, 128),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(val_dir,
                                            target_size = (128, 128),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 2144 images belonging to 3 classes.
# Found 307 images belonging to 3 classes.

# %% [markdown]
# ## Training The Model

# %%
# train the convolutional auto encoder
print("[INFO] training auto encoder...")
H = vgg16.fit(
    training_set,
    shuffle=True,
    validation_data=test_set,
    epochs=EPOCHS,
    callbacks = [checkpoint_callback],
    batch_size=BS)
# Out:
# [INFO] training auto encoder...
# Epoch 1/100
# 67/67 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.6908
# Epoch 00001: val_loss improved from inf to 0.70481, saving model to training_3_subclass_cp/cp.ckpt
# 67/67 [==============================] - 62s 706ms/step - loss: 0.6892 - accuracy: 0.6908 - val_loss: 0.7048 - val_accuracy: 0.6775
# Epoch 2/100
# 67/67 [==============================] - ETA: 0s - loss: 0.4635 - accuracy: 0.8186
# Epoch 00002: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.4635 - accuracy: 0.8186 - val_loss: 0.7384 - val_accuracy: 0.6515
# Epoch 3/100
# 67/67 [==============================] - ETA: 0s - loss: 0.3889 - accuracy: 0.8535
# Epoch 00003: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 638ms/step - loss: 0.3889 - accuracy: 0.8535 - val_loss: 0.7962 - val_accuracy: 0.6547
# Epoch 4/100
# 67/67 [==============================] - ETA: 0s - loss: 0.3372 - accuracy: 0.8731
# Epoch 00004: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.3372 - accuracy: 0.8731 - val_loss: 0.9306 - val_accuracy: 0.6026
# Epoch 5/100
# 67/67 [==============================] - ETA: 0s - loss: 0.3016 - accuracy: 0.8857
# Epoch 00005: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.3016 - accuracy: 0.8857 - val_loss: 0.8743 - val_accuracy: 0.6547
# Epoch 6/100
# 67/67 [==============================] - ETA: 0s - loss: 0.2903 - accuracy: 0.8932
# Epoch 00006: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.2903 - accuracy: 0.8932 - val_loss: 0.8481 - val_accuracy: 0.6482
# Epoch 7/100
# 67/67 [==============================] - ETA: 0s - loss: 0.2501 - accuracy: 0.9053
# Epoch 00007: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 637ms/step - loss: 0.2501 - accuracy: 0.9053 - val_loss: 1.2819 - val_accuracy: 0.5537
# Epoch 8/100
# 67/67 [==============================] - ETA: 0s - loss: 0.2222 - accuracy: 0.9226
# Epoch 00008: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.2222 - accuracy: 0.9226 - val_loss: 0.7914 - val_accuracy: 0.6775
# Epoch 9/100
# 67/67 [==============================] - ETA: 0s - loss: 0.2223 - accuracy: 0.9235
# Epoch 00009: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 641ms/step - loss: 0.2223 - accuracy: 0.9235 - val_loss: 1.1852 - val_accuracy: 0.5993
# Epoch 10/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1947 - accuracy: 0.9282
# Epoch 00010: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 637ms/step - loss: 0.1947 - accuracy: 0.9282 - val_loss: 1.1638 - val_accuracy: 0.6124
# Epoch 11/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1903 - accuracy: 0.9272
# Epoch 00011: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.1903 - accuracy: 0.9272 - val_loss: 1.5191 - val_accuracy: 0.5603
# Epoch 12/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9314
# Epoch 00012: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 645ms/step - loss: 0.1778 - accuracy: 0.9314 - val_loss: 1.6243 - val_accuracy: 0.5765
# Epoch 13/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9482
# Epoch 00013: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 637ms/step - loss: 0.1499 - accuracy: 0.9482 - val_loss: 1.1813 - val_accuracy: 0.6384
# Epoch 14/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1523 - accuracy: 0.9487
# Epoch 00014: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.1523 - accuracy: 0.9487 - val_loss: 1.5924 - val_accuracy: 0.5537
# Epoch 15/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.9501
# Epoch 00015: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.1477 - accuracy: 0.9501 - val_loss: 1.5409 - val_accuracy: 0.5733
# Epoch 16/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9478
# Epoch 00016: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 636ms/step - loss: 0.1424 - accuracy: 0.9478 - val_loss: 1.2389 - val_accuracy: 0.6221
# Epoch 17/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9473
# Epoch 00017: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.1385 - accuracy: 0.9473 - val_loss: 1.2921 - val_accuracy: 0.6156
# Epoch 18/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.9487
# Epoch 00018: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.1497 - accuracy: 0.9487 - val_loss: 1.4765 - val_accuracy: 0.5798
# Epoch 19/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9632
# Epoch 00019: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.1073 - accuracy: 0.9632 - val_loss: 1.4389 - val_accuracy: 0.5928
# Epoch 20/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.9571
# Epoch 00020: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 639ms/step - loss: 0.1215 - accuracy: 0.9571 - val_loss: 1.2819 - val_accuracy: 0.6091
# Epoch 21/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9650
# Epoch 00021: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 641ms/step - loss: 0.1014 - accuracy: 0.9650 - val_loss: 1.4911 - val_accuracy: 0.5993
# Epoch 22/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9655
# Epoch 00022: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 639ms/step - loss: 0.1010 - accuracy: 0.9655 - val_loss: 1.4798 - val_accuracy: 0.6091
# Epoch 23/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9674
# Epoch 00023: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 639ms/step - loss: 0.0978 - accuracy: 0.9674 - val_loss: 1.8058 - val_accuracy: 0.5765
# Epoch 24/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9669
# Epoch 00024: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 638ms/step - loss: 0.0955 - accuracy: 0.9669 - val_loss: 1.7442 - val_accuracy: 0.5863
# Epoch 25/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9678
# Epoch 00025: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 635ms/step - loss: 0.0918 - accuracy: 0.9678 - val_loss: 2.1040 - val_accuracy: 0.5505
# Epoch 26/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9697
# Epoch 00026: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0884 - accuracy: 0.9697 - val_loss: 1.5924 - val_accuracy: 0.5961
# Epoch 27/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9701
# Epoch 00027: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 640ms/step - loss: 0.0858 - accuracy: 0.9701 - val_loss: 1.9108 - val_accuracy: 0.5668
# Epoch 28/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9748
# Epoch 00028: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 637ms/step - loss: 0.0753 - accuracy: 0.9748 - val_loss: 1.4739 - val_accuracy: 0.6254
# Epoch 29/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9720
# Epoch 00029: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 639ms/step - loss: 0.0815 - accuracy: 0.9720 - val_loss: 1.4066 - val_accuracy: 0.6287
# Epoch 30/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9729
# Epoch 00030: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0817 - accuracy: 0.9729 - val_loss: 1.5564 - val_accuracy: 0.6156
# Epoch 31/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 0.9674
# Epoch 00031: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0922 - accuracy: 0.9674 - val_loss: 1.8552 - val_accuracy: 0.5603
# Epoch 32/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9664
# Epoch 00032: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 636ms/step - loss: 0.0839 - accuracy: 0.9664 - val_loss: 1.8122 - val_accuracy: 0.5798
# Epoch 33/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9790
# Epoch 00033: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0637 - accuracy: 0.9790 - val_loss: 1.6370 - val_accuracy: 0.6319
# Epoch 34/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9646
# Epoch 00034: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.0958 - accuracy: 0.9646 - val_loss: 1.1814 - val_accuracy: 0.6678
# Epoch 35/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9688
# Epoch 00035: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 638ms/step - loss: 0.0976 - accuracy: 0.9688 - val_loss: 2.4563 - val_accuracy: 0.5472
# Epoch 36/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9818
# Epoch 00036: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0572 - accuracy: 0.9818 - val_loss: 1.7006 - val_accuracy: 0.6156
# Epoch 37/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9846
# Epoch 00037: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 641ms/step - loss: 0.0511 - accuracy: 0.9846 - val_loss: 1.3471 - val_accuracy: 0.6547
# Epoch 38/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9804
# Epoch 00038: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0603 - accuracy: 0.9804 - val_loss: 1.7501 - val_accuracy: 0.6156
# Epoch 39/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0427 - accuracy: 0.9907
# Epoch 00039: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 636ms/step - loss: 0.0427 - accuracy: 0.9907 - val_loss: 2.0046 - val_accuracy: 0.5993
# Epoch 40/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0647 - accuracy: 0.9753
# Epoch 00040: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0647 - accuracy: 0.9753 - val_loss: 2.2867 - val_accuracy: 0.5765
# Epoch 41/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9799
# Epoch 00041: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.0509 - accuracy: 0.9799 - val_loss: 2.3801 - val_accuracy: 0.5700
# Epoch 42/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9813
# Epoch 00042: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 638ms/step - loss: 0.0533 - accuracy: 0.9813 - val_loss: 2.0993 - val_accuracy: 0.5993
# Epoch 43/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9771
# Epoch 00043: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0616 - accuracy: 0.9771 - val_loss: 2.9240 - val_accuracy: 0.5375
# Epoch 44/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0698 - accuracy: 0.9748
# Epoch 00044: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0698 - accuracy: 0.9748 - val_loss: 2.0950 - val_accuracy: 0.5863
# Epoch 45/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9851
# Epoch 00045: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.0431 - accuracy: 0.9851 - val_loss: 2.6350 - val_accuracy: 0.5570
# Epoch 46/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9860
# Epoch 00046: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 637ms/step - loss: 0.0431 - accuracy: 0.9860 - val_loss: 2.5048 - val_accuracy: 0.5668
# Epoch 47/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9879
# Epoch 00047: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0380 - accuracy: 0.9879 - val_loss: 2.9656 - val_accuracy: 0.5342
# Epoch 48/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9902
# Epoch 00048: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0336 - accuracy: 0.9902 - val_loss: 1.9624 - val_accuracy: 0.6156
# Epoch 49/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9860
# Epoch 00049: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 639ms/step - loss: 0.0416 - accuracy: 0.9860 - val_loss: 2.7366 - val_accuracy: 0.5570
# Epoch 50/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9795
# Epoch 00050: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.0520 - accuracy: 0.9795 - val_loss: 2.1380 - val_accuracy: 0.6026
# Epoch 51/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9865
# Epoch 00051: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 640ms/step - loss: 0.0425 - accuracy: 0.9865 - val_loss: 3.1878 - val_accuracy: 0.5179
# Epoch 52/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9809
# Epoch 00052: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0487 - accuracy: 0.9809 - val_loss: 1.5243 - val_accuracy: 0.6352
# Epoch 53/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9804
# Epoch 00053: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 638ms/step - loss: 0.0587 - accuracy: 0.9804 - val_loss: 2.6797 - val_accuracy: 0.5440
# Epoch 54/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0439 - accuracy: 0.9855
# Epoch 00054: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0439 - accuracy: 0.9855 - val_loss: 1.7413 - val_accuracy: 0.6221
# Epoch 55/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9883
# Epoch 00055: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0351 - accuracy: 0.9883 - val_loss: 2.4736 - val_accuracy: 0.5863
# Epoch 56/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9851
# Epoch 00056: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 637ms/step - loss: 0.0445 - accuracy: 0.9851 - val_loss: 2.3397 - val_accuracy: 0.5733
# Epoch 57/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 0.9851
# Epoch 00057: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0415 - accuracy: 0.9851 - val_loss: 1.8727 - val_accuracy: 0.6124
# Epoch 58/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9925
# Epoch 00058: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.0288 - accuracy: 0.9925 - val_loss: 2.4144 - val_accuracy: 0.5798
# Epoch 59/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9939
# Epoch 00059: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 645ms/step - loss: 0.0253 - accuracy: 0.9939 - val_loss: 2.1846 - val_accuracy: 0.6059
# Epoch 60/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9907
# Epoch 00060: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 640ms/step - loss: 0.0289 - accuracy: 0.9907 - val_loss: 2.3338 - val_accuracy: 0.5993
# Epoch 61/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9939
# Epoch 00061: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.0233 - accuracy: 0.9939 - val_loss: 2.1965 - val_accuracy: 0.6156
# Epoch 62/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9930
# Epoch 00062: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0255 - accuracy: 0.9930 - val_loss: 2.6064 - val_accuracy: 0.5798
# Epoch 63/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9907
# Epoch 00063: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 638ms/step - loss: 0.0281 - accuracy: 0.9907 - val_loss: 2.9733 - val_accuracy: 0.5603
# Epoch 64/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9851
# Epoch 00064: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0387 - accuracy: 0.9851 - val_loss: 1.7590 - val_accuracy: 0.6384
# Epoch 65/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9921
# Epoch 00065: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.0283 - accuracy: 0.9921 - val_loss: 2.4293 - val_accuracy: 0.5896
# Epoch 66/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9958
# Epoch 00066: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 645ms/step - loss: 0.0186 - accuracy: 0.9958 - val_loss: 2.1270 - val_accuracy: 0.6156
# Epoch 67/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9799
# Epoch 00067: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 640ms/step - loss: 0.0575 - accuracy: 0.9799 - val_loss: 3.4640 - val_accuracy: 0.5277
# Epoch 68/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9865
# Epoch 00068: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0378 - accuracy: 0.9865 - val_loss: 2.1843 - val_accuracy: 0.6091
# Epoch 69/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9949
# Epoch 00069: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 638ms/step - loss: 0.0236 - accuracy: 0.9949 - val_loss: 2.6392 - val_accuracy: 0.5798
# Epoch 70/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9925
# Epoch 00070: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 645ms/step - loss: 0.0240 - accuracy: 0.9925 - val_loss: 3.1768 - val_accuracy: 0.5505
# Epoch 71/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9930
# Epoch 00071: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 647ms/step - loss: 0.0255 - accuracy: 0.9930 - val_loss: 2.8198 - val_accuracy: 0.5668
# Epoch 72/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9935
# Epoch 00072: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 645ms/step - loss: 0.0250 - accuracy: 0.9935 - val_loss: 2.6044 - val_accuracy: 0.5798
# Epoch 73/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9939
# Epoch 00073: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 637ms/step - loss: 0.0196 - accuracy: 0.9939 - val_loss: 2.8804 - val_accuracy: 0.5505
# Epoch 74/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9930
# Epoch 00074: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0244 - accuracy: 0.9930 - val_loss: 2.9731 - val_accuracy: 0.5700
# Epoch 75/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9916
# Epoch 00075: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0247 - accuracy: 0.9916 - val_loss: 3.0277 - val_accuracy: 0.5635
# Epoch 76/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9860
# Epoch 00076: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 636ms/step - loss: 0.0370 - accuracy: 0.9860 - val_loss: 2.5947 - val_accuracy: 0.5798
# Epoch 77/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9851
# Epoch 00077: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.0411 - accuracy: 0.9851 - val_loss: 2.3366 - val_accuracy: 0.6156
# Epoch 78/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9827
# Epoch 00078: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.0456 - accuracy: 0.9827 - val_loss: 2.0605 - val_accuracy: 0.6221
# Epoch 79/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9911
# Epoch 00079: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0286 - accuracy: 0.9911 - val_loss: 2.0067 - val_accuracy: 0.6515
# Epoch 80/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9823
# Epoch 00080: val_loss did not improve from 0.70481
# 67/67 [==============================] - 44s 650ms/step - loss: 0.0486 - accuracy: 0.9823 - val_loss: 2.5860 - val_accuracy: 0.5961
# Epoch 81/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9911
# Epoch 00081: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 645ms/step - loss: 0.0289 - accuracy: 0.9911 - val_loss: 1.8761 - val_accuracy: 0.6384
# Epoch 82/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9958
# Epoch 00082: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 636ms/step - loss: 0.0216 - accuracy: 0.9958 - val_loss: 2.7140 - val_accuracy: 0.5733
# Epoch 83/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9939
# Epoch 00083: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 647ms/step - loss: 0.0176 - accuracy: 0.9939 - val_loss: 3.0120 - val_accuracy: 0.5733
# Epoch 84/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9879
# Epoch 00084: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0273 - accuracy: 0.9879 - val_loss: 2.2668 - val_accuracy: 0.6156
# Epoch 85/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9944
# Epoch 00085: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 2.9138 - val_accuracy: 0.5635
# Epoch 86/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9879
# Epoch 00086: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 637ms/step - loss: 0.0351 - accuracy: 0.9879 - val_loss: 1.5837 - val_accuracy: 0.6612
# Epoch 87/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9781
# Epoch 00087: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 645ms/step - loss: 0.0559 - accuracy: 0.9781 - val_loss: 2.8387 - val_accuracy: 0.5831
# Epoch 88/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9958
# Epoch 00088: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0169 - accuracy: 0.9958 - val_loss: 2.8668 - val_accuracy: 0.5896
# Epoch 89/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9958
# Epoch 00089: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 640ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 3.5578 - val_accuracy: 0.5570
# Epoch 90/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9967
# Epoch 00090: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 644ms/step - loss: 0.0145 - accuracy: 0.9967 - val_loss: 2.5285 - val_accuracy: 0.6189
# Epoch 91/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9902
# Epoch 00091: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.0251 - accuracy: 0.9902 - val_loss: 3.6830 - val_accuracy: 0.5472
# Epoch 92/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9907
# Epoch 00092: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 636ms/step - loss: 0.0257 - accuracy: 0.9907 - val_loss: 3.2893 - val_accuracy: 0.5603
# Epoch 93/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9921
# Epoch 00093: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 643ms/step - loss: 0.0218 - accuracy: 0.9921 - val_loss: 2.3558 - val_accuracy: 0.6059
# Epoch 94/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0987 - accuracy: 0.9636
# Epoch 00094: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 647ms/step - loss: 0.0987 - accuracy: 0.9636 - val_loss: 2.9860 - val_accuracy: 0.5570
# Epoch 95/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9865
# Epoch 00095: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 637ms/step - loss: 0.0412 - accuracy: 0.9865 - val_loss: 2.2493 - val_accuracy: 0.5993
# Epoch 96/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9930
# Epoch 00096: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0203 - accuracy: 0.9930 - val_loss: 2.6689 - val_accuracy: 0.5961
# Epoch 97/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9972
# Epoch 00097: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0116 - accuracy: 0.9972 - val_loss: 2.7845 - val_accuracy: 0.5896
# Epoch 98/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9953
# Epoch 00098: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 637ms/step - loss: 0.0155 - accuracy: 0.9953 - val_loss: 3.4854 - val_accuracy: 0.5537
# Epoch 99/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9944
# Epoch 00099: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 642ms/step - loss: 0.0167 - accuracy: 0.9944 - val_loss: 2.4057 - val_accuracy: 0.6059
# Epoch 100/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9925
# Epoch 00100: val_loss did not improve from 0.70481
# 67/67 [==============================] - 43s 641ms/step - loss: 0.0212 - accuracy: 0.9925 - val_loss: 3.1876 - val_accuracy: 0.5570

# %% [markdown]
# ## Saved Result Graphic (.json) and Model Trained (h5)

# %%
with open(history_path, 'w') as f:
    json.dump(H.history, f)
vgg16.save(model_path)

# %%
reconstruction_score = vgg16.evaluate(test_set, verbose=0)
print("Convolutional autoencoder score:", reconstruction_score)
print("Test Loss:", reconstruction_score[0])
print("Test Accuracy:", reconstruction_score[1])
# Out:
# Convolutional autoencoder score: [3.187638521194458, 0.5570032596588135]
# Test Loss: 3.187638521194458
# Test Accuracy: 0.5570032596588135

# %% [markdown]
# # Extract Feature Stage

# %% [markdown]
# ## Load already trained model and extracting feature

# %%
print("[INFO] encoding images...")
features = vgg16.predict(training_set)
features
# Out:
# [INFO] encoding images...
# array([[3.5047538e-03, 5.4712895e-02, 9.9992085e-01],
#        [9.9943703e-01, 4.2158175e-02, 8.2400329e-03],
#        [1.6148902e-02, 3.3444781e-03, 9.9998891e-01],
#        ...,
#        [7.8399935e-06, 8.4738326e-01, 9.9992931e-01],
#        [9.9991608e-01, 3.7422050e-02, 1.1518005e-03],
#        [2.1503202e-04, 3.3160746e-02, 9.9998975e-01]], dtype=float32)

# %% [markdown]
# ## Create mapping feature included location images, label, feature and indexing number

# %%
indexes = list(range(0, train_x.shape[0]))
features_array = [[float(x) for x in y] for y in features]
labels = [path.split("/")[5] for path in dataset_train]
data = {"indexes": indexes, "features": features_array, "locations": dataset_train, "labels":labels}

# %% [markdown]
# ## Saved model feature (already mapped) as json

# %%
with open(feature_path, 'w') as f:
    json.dump(data, f)

# %% [markdown]
# # Retrieval Test Stage

# %% [markdown]
# ## Euclidean function

# %%
def euclidean(a, b):
	# compute and return the euclidean distance between two vectors
	return np.linalg.norm(a - b)

# %% [markdown]
# ## Perform search function
# ```
# Default max result from search is 5
# ```

# %%
def perform_search(query_features, indexed_train, max_results=5):
	retrieved = []
	for idx in range(0, len(indexed_train["features"])):
		distance = euclidean(query_features, indexed_train["features"][idx])
		retrieved.append((distance, idx))
	retrieved = sorted(retrieved)[:max_results]
	return retrieved

# %% [markdown]
# ## Load test images

# %%
print("[INFO] indexing file images BreaKHis dataset...")
# indexing file images
dataset = []
for class_item in class_dir:
    cur_dir = os.path.join(base_dir, 'test', class_item)
    for file in os.listdir(cur_dir):
        dataset.append(os.path.join(cur_dir, file))
print("test len to retrieving:", len(dataset))
print("[INFO] load test images BreaKHis dataset...")
#  load images
images = []
for image_path in dataset:
    if ".png" in image_path:
        image = cv2.imread(image_path)
        image = cv2.resize(image, IMAGE_SIZE)
        images.append(image)
# Out:
# [INFO] indexing file images BreaKHis dataset...
# test len to retrieving: 613
# [INFO] load test images BreaKHis dataset...

# %% [markdown]
# ## Normalization

# %%
# normalization
print("[INFO] normalization...")
test_x = np.array(images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %% [markdown]
# ## Load the model and feature already extracted

# %%
# auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
# # load our auto_encoder from disk
# print("[INFO] loading auto encoder model...")
# auto_encoder.load_weights(checkpoint_path)
with open(feature_path) as f:
  training_indexed = json.load(f)

# # create the encoder model which consists of *just* the encoder
# # portion of the auto encoder
# encoder = Model(inputs=auto_encoder.input,
# 	outputs=auto_encoder.get_layer("encoded").output)

# # quantify the contents of our input images using the encoder
# print("[INFO] encoding images...")
features_retrieved = vgg16.predict(test_x)

# %% [markdown]
# ## Perform search and retrieval based test images

# %%
query_indexes = list(range(0, test_x.shape[0]))
label_builder = list(np.unique(training_indexed["labels"]))
class_builder = {label_unique:[] for label_unique in label_builder}
recalls = copy.deepcopy(class_builder)
precisions = copy.deepcopy(class_builder)
accuracies = copy.deepcopy(class_builder)
# loop over the testing indexes
for i in query_indexes:
    queryFeatures = features_retrieved[i]
    results = perform_search(queryFeatures, training_indexed, max_results=10)
    labels_ret = [training_indexed["labels"][r[1]] for r in results]
    label_true = dataset[i].split("/")[5]
    label_trues = [label_true for _ in labels_ret]
    recall = metric.recall_score(label_trues, labels_ret, average='weighted')
    precision = metric.precision_score(label_trues, labels_ret, average='weighted')
    accuracy = metric.accuracy_score(label_trues, labels_ret)
    recalls[label_true].append(recall)
    precisions[label_true].append(precision)
    accuracies[label_true].append(accuracy)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Print the recall and precision values

# %%
print("recall values:")
comb_recall, comb_precision = [], []
for key in recalls.keys():
    average_val = np.average(recalls[key])
    print(key, average_val)
    comb_recall.append(average_val)
print("combined recall", np.average(comb_recall))

print("\nprecision values:")
for key in precisions.keys():
    average_val = np.average(precisions[key])
    print(key, average_val) 
    comb_precision.append(average_val)
print("combined precision", np.average(comb_precision))
# Out:
# recall values:
# glioma 0.44105263157894736
# meningioma 0.25774647887323937
# pituitary 0.32043010752688167
# combined recall 0.33974307265968945
#
# precision values:
# glioma 1.0
# meningioma 0.9225352112676056
# pituitary 0.9731182795698925
# combined precision 0.965217830279166

# %%
def build_montages(image_list, image_shape, montage_shape):
    if len(image_shape) != 2:
        raise Exception('image shape must be list or tuple of length 2 (rows, cols)')
    if len(montage_shape) != 2:
        raise Exception('montage shape must be list or tuple of length 2 (rows, cols)')
    image_montages = []
    # start with black canvas to draw images onto
    montage_image = np.zeros(shape=(image_shape[1] * (montage_shape[1]), image_shape[0] * montage_shape[0], 3),
                          dtype=np.uint8)
    cursor_pos = [0, 0]
    start_new_img = False
    for img in image_list:
        if type(img).__module__ != np.__name__:
            raise Exception('input of type {} is not a valid numpy array'.format(type(img)))
        start_new_img = False
        img = cv2.resize(img, image_shape)
        # draw image to black canvas
        montage_image[cursor_pos[1]:cursor_pos[1] + image_shape[1], cursor_pos[0]:cursor_pos[0] + image_shape[0]] = img
        cursor_pos[0] += image_shape[0]  # increment cursor x position
        if cursor_pos[0] >= montage_shape[0] * image_shape[0]:
            cursor_pos[1] += image_shape[1]  # increment cursor y position
            cursor_pos[0] = 0
            if cursor_pos[1] >= montage_shape[1] * image_shape[1]:
                cursor_pos = [0, 0]
                image_montages.append(montage_image)
                # reset black canvas
                montage_image = np.zeros(shape=(image_shape[1] * (montage_shape[1]), image_shape[0] * montage_shape[0], 3),
                                      dtype=np.uint8)
                start_new_img = True
    if start_new_img is False:
        image_montages.append(montage_image)  # add unfinished montage
    return image_montages

# %%
from PIL import Image

queryIdx = 3 # Input Index for which images 

queryFeatures = features_retrieved[queryIdx]
results = perform_search(queryFeatures, training_indexed, max_results=5)

imgs = []
result_path = []

# loop over the results
for (d, j) in results:
    img = np.array(Image.open(dataset_train[j]))
    result_path.append(dataset_train[j])
    imgs.append(img)

# display the query image
plt.title(dataset[queryIdx].split("/")[5])
plt.imshow(np.array(Image.open(dataset[queryIdx])))

plt.figure(figsize=(30,30))
columns = 5
for i, image in enumerate(imgs):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    result_label = result_path[i].split("/")[5]
    plt.title(result_label)
    plt.imshow(image)

# %%
queryIdx = 480 # Input Index for which images 

queryFeatures = features_retrieved[queryIdx]
results = perform_search(queryFeatures, training_indexed, max_results=5)

imgs = []
result_path = []

# loop over the results
for (d, j) in results:
    img = np.array(Image.open(dataset_train[j]))
    result_path.append(dataset_train[j])
    imgs.append(img)

# display the query image
plt.title(dataset[queryIdx].split("/")[5])
plt.imshow(np.array(Image.open(dataset[queryIdx])))

plt.figure(figsize=(30,30))
columns = 5
for i, image in enumerate(imgs):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    result_label = result_path[i].split("/")[5]
    plt.title(result_label)
    plt.imshow(image)

# %%
queryIdx = 330 # Input Index for which images 

queryFeatures = features_retrieved[queryIdx]
results = perform_search(queryFeatures, training_indexed, max_results=5)

imgs = []
result_path = []

# loop over the results
for (d, j) in results:
    img = np.array(Image.open(dataset_train[j]))
    result_path.append(dataset_train[j])
    imgs.append(img)

# display the query image
plt.title(dataset[queryIdx].split("/")[5])
plt.imshow(np.array(Image.open(dataset[queryIdx])))

plt.figure(figsize=(30,30))
columns = 5
for i, image in enumerate(imgs):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    result_label = result_path[i].split("/")[5]
    plt.title(result_label)
    plt.imshow(image)

# %%
vgg16.save('vgg16_model.h5')
